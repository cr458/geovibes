# %% [markdown]
# ## Run this first if you want NDVI/NDWI basemaps

# %%
import ee
ee.Authenticate()
# Out:
# True

# %% [markdown]
# ## Vibes

# %%
# %load_ext autoreload
# %autoreload 2

from geovibes.ui import GeoVibes

vibes = GeoVibes.create(config_path='config.yaml', verbose=True)
# Out:
# Initializing GeoVibes...
# 📍 Starting with AOI: alabama
# 💾 Starting with database: alabama_google
# 💾 Connecting to local database: /Users/noah/Dev/geovibes/local_databases/alabama_google.db
# ✅ Database connection established successfully
# ⚠️  Failed to create Earth Engine boundary: 'GeoDataFrame' object has no attribute 'union_all'
# ⚠️  NDVI/NDWI basemaps will be unavailable
# 🗺️  spatial extension loaded for geometry support
# 🔍 Detected embedding dimension: 64
# 📍 Using boundary file: /Users/noah/Dev/geovibes/geometries/alabama.geojson
# Building UI...
# HTML(value='\n        <style>\n        .widget-toggle-buttons button:nth-child(1).mod-active {\n            ba…
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# Cell In[1], line 6
#       2 get_ipython().run_line_magic('autoreload', '2')
#       4 from geovibes.ui import GeoVibes
# ...

# %%
Y
